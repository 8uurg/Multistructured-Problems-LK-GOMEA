# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
# import rpy2
# %load_ext rpy2.ipython
# Out:
# C:\Program Files\Python310\lib\site-packages\rpy2\robjects\packages.py:366: UserWarning: The symbol 'quartz' is not in this R namespace/package.
#   warnings.warn(

# %%
# %%R
# library(ggplot2)
# library(scales)
# library(patchwork)
#
# library(gt)
# library(xtable)
# library(dplyr)
# library(tidyr)
# Out:
# R[write to console]:
# Attaching package: 'dplyr'
#
#
# R[write to console]: The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Load data

# %%
# name_dict = {
#     "Kernel-GOMEA---Asymmetric": "Kernel GOMEA - Asymmetric",
#     "Kernel-GOMEA---Symmetric": "Kernel GOMEA - Symmetric",
# }
name_dict = {
    "DSMGA2": "DSMGA-II",
    "Kernel-GOMEA---Asymmetric": "LK-GOMEA (Asym)",
    "Kernel-GOMEA---Symmetric": "LK-GOMEA (Sym)",
}

# %%
res_maxcut = pd.concat([
    pd.read_csv("./paper_singleobjective_e963b42_maxcut.csv.gz"), # Standard run data
    pd.read_csv("2021-12-24-paper_singleobjective_extra_1fc247f_maxcut.csv.gz"), # data for l=200 for maxcut
])
res_maxcut["kind"] = "MaxCut"

res_wo_maxcut = pd.concat([
    pd.read_csv("./2022-01-25-paper_singleobjective_19451c0_wo_maxcut.csv.gz"), # Standard run data
])
res_wo_maxcut["kind"] = "Worst-of-MaxCuts"

res = pd.concat([
    res_maxcut,
    res_wo_maxcut
])

res["approach"] = res["approach"].replace(name_dict)
res
# Out:
#        #evaluations  time(ms)  fitness  isKey  populationSize  \
# 0                 1         0     28.0      0               2
# 1                 5         0     29.0      1               4
# 2                 1         0   7464.0      0               2
# 3                 3         4   7508.0      0               4
# 4                 5         4   7510.0      0               4
# ...             ...       ...      ...    ...             ...
# 14346         19284       134   2015.0      0              16
# 14347         21905       150   2019.0      0              32
# 14348         30937       185   2020.0      0              32
# 14349         37598       216   2021.0      0              32
# 14350         37950       218   2025.0      1              32
#
#                                                 solution         approach  \
# 0                                                 101011   LK-GOMEA (Sym)
# 1                                                 011100   LK-GOMEA (Sym)
# 2      0010001000100000101101000100111000101110001100...  LK-GOMEA (Asym)
# 3      0110000100101111101000111111000000001111011101...  LK-GOMEA (Asym)
# 4      0000100101100010110111111101011011111101000000...  LK-GOMEA (Asym)
# ...                                                  ...              ...
# 14346  1110100001111010000101010100001010111010111101...         DSMGA-II
# 14347  0110101100101110010101010000000010111010111101...         DSMGA-II
# 14348  0110100101101010010101010100000010111010111101...         DSMGA-II
# 14349  0110100101101010010101010100001010111010111101...         DSMGA-II
# 14350  0110100101101010000101010100001010111010111101...         DSMGA-II
#
#        run    l              kind
# 0       12    6            MaxCut
# 1       12    6            MaxCut
# 2       19  100            MaxCut
# 3       19  100            MaxCut
# 4       19  100            MaxCut
# ...    ...  ...               ...
# 14346   11   50  Worst-of-MaxCuts
# 14347   11   50  Worst-of-MaxCuts
# 14348   11   50  Worst-of-MaxCuts
# 14349   11   50  Worst-of-MaxCuts
# 14350   11   50  Worst-of-MaxCuts
#
# [46268 rows x 10 columns]

# %%
setting_columns = ["approach", "l", "kind"]
run_columns = setting_columns + ["run"]

# %% [markdown]
# # Scalability: #evaluations
# How many evaluations does it take to get to the optimum?

# %%
# Derive the hitting point in #evaluations
def process_run(run_df):
    sorted_run_df = run_df.sort_values("#evaluations")
    potential_keypoint = sorted_run_df.iloc[-1]
    if potential_keypoint["isKey"]:
        return potential_keypoint["#evaluations"]
    else:
        return np.nan

hitting_evaluations = res.groupby(run_columns).apply(process_run).rename("hitting #evaluations").reset_index()

# %%
# Quick check if everything is finite (not the case if not all runs hit the optimum!)
def all_finite(df):
    return np.isfinite(df["hitting #evaluations"]).all()

hef = hitting_evaluations.groupby(setting_columns).apply(all_finite).rename("all runs finite").reset_index()
hitting_evaluations_af = pd.merge(hitting_evaluations, hef)
hitting_evaluations_af = hitting_evaluations_af[hitting_evaluations_af["all runs finite"]].copy()

# %%
# Compute statistics - replacing nan with inf
hitting_evaluations_q = hitting_evaluations.fillna(np.inf).groupby(setting_columns)["hitting #evaluations"].quantile([0.05, 0.5, 0.95]).unstack().fillna(np.inf).reset_index()
# hitting_evaluations_q.loc[~np.isfinite(hitting_evaluations_q[0.9]) & np.isfinite(hitting_evaluations_q[0.5]), 0.9] = max_evaluations
# Remove points where median is inf.
hitting_evaluations_q = hitting_evaluations_q[np.isfinite(hitting_evaluations_q[0.5])]
hitting_evaluations_q
# Out:
#            approach    l              kind        0.05         0.5  \
# 0          DSMGA-II    6            MaxCut        4.00        16.0
# 1          DSMGA-II    6  Worst-of-MaxCuts        4.00        12.0
# 2          DSMGA-II   12            MaxCut        6.45       204.0
# 3          DSMGA-II   12  Worst-of-MaxCuts       75.50       529.5
# 4          DSMGA-II   25            MaxCut      725.10      3552.5
# 5          DSMGA-II   25  Worst-of-MaxCuts     1008.15      3785.5
# 6          DSMGA-II   50            MaxCut    14241.00     35211.0
# 7          DSMGA-II   50  Worst-of-MaxCuts    16466.60     55128.0
# 8          DSMGA-II  100            MaxCut   324693.95    895764.5
# 9          DSMGA-II  100  Worst-of-MaxCuts  7502261.05  52927575.0
# 11            GOMEA    6            MaxCut        1.00        39.0
# 12            GOMEA    6  Worst-of-MaxCuts        1.00        37.0
# 13            GOMEA   12            MaxCut       62.05       351.0
# 14            GOMEA   12  Worst-of-MaxCuts      133.15       731.0
# 15            GOMEA   25            MaxCut     1495.35      4793.0
# 16            GOMEA   25  Worst-of-MaxCuts     1513.60      2478.0
# 17            GOMEA   50            MaxCut     4686.80     16851.0
# 18            GOMEA   50  Worst-of-MaxCuts    12221.50     32995.0
# 19            GOMEA  100            MaxCut    62721.80    315904.5
# 20            GOMEA  100  Worst-of-MaxCuts   932270.60  49709152.5
# 21            GOMEA  200            MaxCut  1598925.90   6970920.0
# 22  LK-GOMEA (Asym)    6            MaxCut        1.00        29.0
# 23  LK-GOMEA (Asym)    6  Worst-of-MaxCuts        1.00        29.0
# 24  LK-GOMEA (Asym)   12            MaxCut       69.30       644.5
# 25  LK-GOMEA (Asym)   12  Worst-of-MaxCuts       87.50       668.5
# 26  LK-GOMEA (Asym)   25            MaxCut     1765.65      6390.0
# 27  LK-GOMEA (Asym)   25  Worst-of-MaxCuts     1129.40      7592.5
# 28  LK-GOMEA (Asym)   50            MaxCut    18304.45     52430.0
# 29  LK-GOMEA (Asym)   50  Worst-of-MaxCuts    19923.20     56462.5
# 30  LK-GOMEA (Asym)  100            MaxCut   159468.50    385649.0
# 31  LK-GOMEA (Asym)  100  Worst-of-MaxCuts  1295863.90   7095108.5
# 32  LK-GOMEA (Asym)  200            MaxCut  4630645.60  19345934.0
# 33   LK-GOMEA (Sym)    6            MaxCut        1.00        41.5
# 34   LK-GOMEA (Sym)    6  Worst-of-MaxCuts        1.00        41.0
# 35   LK-GOMEA (Sym)   12            MaxCut       64.60       407.0
# 36   LK-GOMEA (Sym)   12  Worst-of-MaxCuts      112.65       673.0
# 37   LK-GOMEA (Sym)   25            MaxCut     1299.10      4306.5
# 38   LK-GOMEA (Sym)   25  Worst-of-MaxCuts     1111.30      4505.5
# 39   LK-GOMEA (Sym)   50            MaxCut     9645.00     26733.5
# 40   LK-GOMEA (Sym)   50  Worst-of-MaxCuts    12907.45     37644.5
# 41   LK-GOMEA (Sym)  100            MaxCut   119408.10    420570.5
# 42   LK-GOMEA (Sym)  100  Worst-of-MaxCuts   954086.15   5209439.0
# 43   LK-GOMEA (Sym)  200            MaxCut  2383743.80  12374353.5
#
#            0.95
# 0         44.70
# 1         40.30
# 2        361.75
# 3       1335.90
# 4      17106.65
# 5      25230.30
# 6     165371.70
# 7     126525.40
# 8    7514947.95
# 9           inf
# 11       144.65
# 12       147.70
# 13       979.70
# 14      2552.85
# 15     11806.10
# 16     11120.65
# 17     42897.60
# 18    145273.90
# 19    717631.60
# 20          inf
# 21  45434474.40
# 22        87.70
# 23        87.70
# 24      1386.00
# 25      1867.05
# 26     17698.85
# 27     21341.35
# 28    105506.20
# 29    141482.70
# 30    978523.50
# 31  19753780.40
# 32  49902629.15
# 33       116.60
# 34       141.85
# 35      1092.05
# 36      2409.65
# 37     11198.55
# 38     23456.40
# 39     63140.90
# 40     75034.50
# 41   1068873.70
# 42  14694411.75
# 43  52411116.00

# %%
# %%R -i hitting_evaluations_q -w 500 -h 300
# plt <- ggplot(hitting_evaluations_q, aes(x=l, y=`0.5`, ymin=`0.05`, ymax=`0.95`, shape=`approach`, color=`approach`, fill=`approach`)) +
#     geom_line() +
#     geom_point() +
#     geom_ribbon(alpha=0.1, color=NA) +
#     # Nice axis labels courtesy of https://stackoverflow.com/a/18526649/4224646
#     # Now only used for the y-axis
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     #     labels=trans_format("log10", math_format(10^.x))) +
#     # scale_y_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     #     labels=trans_format("log10", math_format(10^.x))
#     # ) +
#     scale_x_log10(
#         breaks=unique(hitting_evaluations_q$l)
#         # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     scale_y_log10(
#         breaks=trans_breaks("log10", function(x) 10^x),
#     labels=trans_format("log10", math_format(10^.x))
#     ) +
#     facet_grid(. ~ `kind`, scales = "free_x") +
#     labs(x=expression("string length (" ~ l ~ ")"), y="#evaluations to optimum") +
#     theme_bw() +
#     theme(strip.background = element_rect(fill = NA, color=NA))
#
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_evals.png")
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_evals.pdf", device=cairo_pdf)
# plt
# Out:
# R[write to console]: Saving 6.94 x 4.17 in image
#
# R[write to console]: Saving 6.94 x 4.17 in image

# %% [markdown]
# # Scalability: Time
# How much time does it take to get to the optimum?

# %%
# Derive the hitting point in #evaluations
def process_run(run_df):
    sorted_run_df = run_df.sort_values("time(ms)")
    potential_keypoint = sorted_run_df.iloc[-1]
    if potential_keypoint["isKey"]:
        return potential_keypoint["time(ms)"] + 1
    else:
        return np.nan

hitting_time = res.groupby(run_columns).apply(process_run).rename("hitting time (ms)").reset_index()

# %%
# Quick check if everything is finite (not the case if not all runs hit the optimum!)
def all_finite(df):
    return np.isfinite(df["hitting time (ms)"]).all()

hef = hitting_time.groupby(setting_columns).apply(all_finite).rename("all runs finite").reset_index()
hitting_time_af = pd.merge(hitting_time, hef)
hitting_time_af = hitting_time_af[hitting_time_af["all runs finite"]].copy()

# %%
# Compute statistics - replacing nan with inf
hitting_time_q = hitting_time.fillna(np.inf).groupby(setting_columns)["hitting time (ms)"].quantile([0.05, 0.5, 0.95]).unstack().fillna(np.inf).reset_index()
# hitting_time_q.loc[~np.isfinite(hitting_time_q[0.9]) & np.isfinite(hitting_time_q[0.5]), 0.9] = max_evaluations
# Remove points where median is inf.
hitting_time_q = hitting_time_q[np.isfinite(hitting_time_q[0.5])]
hitting_time_q
# Out:
#            approach    l              kind       0.05        0.5         0.95
# 0          DSMGA-II    6            MaxCut       1.00        1.0         2.00
# 1          DSMGA-II    6  Worst-of-MaxCuts       1.00        1.0         2.00
# 2          DSMGA-II   12            MaxCut       1.00        2.0         2.00
# 3          DSMGA-II   12  Worst-of-MaxCuts       1.00        2.0         2.55
# 4          DSMGA-II   25            MaxCut       3.00       11.5        36.65
# 5          DSMGA-II   25  Worst-of-MaxCuts       3.45       10.5        40.30
# 6          DSMGA-II   50            MaxCut      96.30      220.0       880.35
# 7          DSMGA-II   50  Worst-of-MaxCuts     108.30      306.0       626.65
# 8          DSMGA-II  100            MaxCut    6247.35    17009.5    113048.85
# 9          DSMGA-II  100  Worst-of-MaxCuts  115926.85   870892.5          inf
# 11            GOMEA    6            MaxCut       1.00        1.0         2.00
# 12            GOMEA    6  Worst-of-MaxCuts       1.00        1.0         2.00
# 13            GOMEA   12            MaxCut       1.00        2.0         2.00
# 14            GOMEA   12  Worst-of-MaxCuts       1.00        2.0         3.00
# 15            GOMEA   25            MaxCut       4.00       10.0        22.65
# 16            GOMEA   25  Worst-of-MaxCuts       4.00        5.0        14.40
# 17            GOMEA   50            MaxCut      22.00       69.5       170.35
# 18            GOMEA   50  Worst-of-MaxCuts      41.40       96.5       423.65
# 19            GOMEA  100            MaxCut     761.05     3758.0      8598.65
# 20            GOMEA  100  Worst-of-MaxCuts   10010.15  2203303.0          inf
# 21            GOMEA  200            MaxCut   77903.15   348989.0   4482579.00
# 22  LK-GOMEA (Asym)    6            MaxCut       1.00        1.0         2.00
# 23  LK-GOMEA (Asym)    6  Worst-of-MaxCuts       1.00        1.0         2.00
# 24  LK-GOMEA (Asym)   12            MaxCut       1.45        4.0         7.55
# 25  LK-GOMEA (Asym)   12  Worst-of-MaxCuts       2.00        4.5         8.55
# 26  LK-GOMEA (Asym)   25            MaxCut      18.40       51.5       124.05
# 27  LK-GOMEA (Asym)   25  Worst-of-MaxCuts      15.00       57.5       159.40
# 28  LK-GOMEA (Asym)   50            MaxCut     315.05      793.0      1458.35
# 29  LK-GOMEA (Asym)   50  Worst-of-MaxCuts     316.90      759.5      2050.75
# 30  LK-GOMEA (Asym)  100            MaxCut    5366.40    12511.5     32582.45
# 31  LK-GOMEA (Asym)  100  Worst-of-MaxCuts   45578.75   360411.5   1382710.90
# 32  LK-GOMEA (Asym)  200            MaxCut  476437.00  2629480.5   9461073.50
# 33   LK-GOMEA (Sym)    6            MaxCut       1.00        1.0         2.00
# 34   LK-GOMEA (Sym)    6  Worst-of-MaxCuts       1.00        1.0         2.00
# 35   LK-GOMEA (Sym)   12            MaxCut       2.00        3.0         6.00
# 36   LK-GOMEA (Sym)   12  Worst-of-MaxCuts       2.00        4.0        10.00
# 37   LK-GOMEA (Sym)   25            MaxCut      13.80       35.0        86.55
# 38   LK-GOMEA (Sym)   25  Worst-of-MaxCuts      11.45       34.0       184.25
# 39   LK-GOMEA (Sym)   50            MaxCut     179.10      445.5      1014.05
# 40   LK-GOMEA (Sym)   50  Worst-of-MaxCuts     198.70      465.0      1031.20
# 41   LK-GOMEA (Sym)  100            MaxCut    4126.10    14281.5     38706.45
# 42   LK-GOMEA (Sym)  100  Worst-of-MaxCuts   32417.75   275196.5   1364123.60
# 43   LK-GOMEA (Sym)  200            MaxCut  225369.55  1616792.0  12006129.95

# %%
# %%R -i hitting_time_q -w 500 -h 300
# plt <- ggplot(hitting_time_q, aes(x=l, y=`0.5`, ymin=`0.05`, ymax=`0.95`, shape=`approach`, color=`approach`, fill=`approach`)) +
#     geom_line() +
#     geom_point() +
#     geom_ribbon(alpha=0.1, color=NA) +
#     # Nice axis labels courtesy of https://stackoverflow.com/a/18526649/4224646
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     #     labels=trans_format("log10", math_format(10^.x))) +
#     scale_y_log10(
#         breaks=trans_breaks("log10", function(x) 10^x),
#         labels=trans_format("log10", math_format(10^.x))
#     ) +
#     scale_x_log10(
#         breaks=unique(hitting_time_q$l)
#     # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     facet_grid(. ~ `kind`, scales = "free_x") +
#     labs(x=expression("string length (" ~ l ~ ")"), y="time (ms) to optimum") +
#     theme_bw() +
#     theme(strip.background = element_rect(fill = NA, color=NA))# +
#     #guides(color=guide_legend(nrow=2,byrow=TRUE), fill=guide_legend(nrow=2, byrow=TRUE), shape=guide_legend(nrow=2, byrow=TRUE),) +
#     #theme(legend.position="bottom")
#
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_time.png")
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_time.pdf", device=cairo_pdf)
# plt
# Out:
# R[write to console]: Saving 6.94 x 4.17 in image
#
# R[write to console]: Saving 6.94 x 4.17 in image

# %% [markdown]
# # Scalability Merged

# %%
# %%R -i hitting_evaluations_q -i hitting_time_q -w 500 -h 200
# plt_eval <- ggplot(hitting_evaluations_q, aes(x=l, y=`0.5`, ymin=`0.05`, ymax=`0.95`, shape=`approach`, color=`approach`, fill=`approach`)) +
#     geom_line() +
#     geom_point() +
#     geom_ribbon(alpha=0.1, color=NA) +
#     # Nice axis labels courtesy of https://stackoverflow.com/a/18526649/4224646
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     # labels=trans_format("log10", math_format(10^.x))) +
#     scale_y_log10(
#         breaks=trans_breaks("log10", function(x) 10^x),
#     labels=trans_format("log10", math_format(10^.x))
#     ) +
#     scale_x_log10(
#         breaks=unique(hitting_evaluations_q$l)
#     # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     facet_grid(. ~ `kind`, scales = "free_x") +
#     labs(x=expression("String length (" ~ l ~ ")"), y="#evaluations", shape="Approach:", color="Approach:", fill="Approach:") +
#     theme_bw() +
#     theme(strip.background = element_rect(fill = NA, color=NA)) +
#     theme(strip.background = element_rect(fill = NA, color=NA)) + theme(
#         axis.text.x = element_blank(),
#         axis.title.x = element_blank(),
#         axis.ticks.x = element_blank()
#     ) +
#     theme(plot.margin = margin(b = 2, unit = "pt"))
#
#
# plt_time <- ggplot(hitting_time_q, aes(x=l, y=`0.5`, ymin=`0.05`, ymax=`0.95`, shape=`approach`, color=`approach`, fill=`approach`)) +
#     geom_line() +
#     geom_point() +
#     geom_ribbon(alpha=0.1, color=NA) +
#     # Nice axis labels courtesy of https://stackoverflow.com/a/18526649/4224646
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     # labels=trans_format("log10", math_format(10^.x))) +
#     scale_y_log10(
#         breaks=trans_breaks("log10", function(x) 10^x),
#     labels=trans_format("log10", math_format(10^.x))
#     ) +
#     scale_x_log10(
#         breaks=unique(hitting_time_q$l)
#     # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     facet_grid(. ~ `kind`, scales = "free_x") +
#     labs(x=expression("String length (" ~ l ~ ")"), y="Time (ms)", shape="Approach:", color="Approach:", fill="Approach:") +
#     theme_bw() +
#     theme(strip.text = element_blank()) + theme(plot.margin = margin(t = 2, unit = "pt"))
#     #guides(color=guide_legend(nrow=2,byrow=TRUE), fill=guide_legend(nrow=2, byrow=TRUE), shape=guide_legend(nrow=2, byrow=TRUE),) +
#
#
# plt <- ((plt_eval + theme(legend.position="bottom")) / (plt_time + theme(legend.position="bottom"))) +
#     plot_layout(guides = 'collect') & theme(legend.position="right")
# # ggsave("./2021-12-23-paper_maxcut_scalability_evalandtime.png")
# # ggsave("./2021-12-23-paper_maxcut_scalability_evalandtime.pdf", device=cairo_pdf)
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_evalandtime.png")
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_evalandtime.pdf", device=cairo_pdf)
# plt
# Out:
# R[write to console]: Saving 6.94 x 2.78 in image
#
# R[write to console]: Saving 6.94 x 2.78 in image

# %%
# %%R -i hitting_evaluations_q -i hitting_time_q -w 500 -h 300
# plt_eval <- ggplot(hitting_evaluations_q, aes(x=l, y=`0.5`, ymin=`0.05`, ymax=`0.95`, shape=`approach`, color=`approach`, fill=`approach`)) +
#     geom_line() +
#     geom_point() +
#     geom_ribbon(alpha=0.1, color=NA) +
#     # Nice axis labels courtesy of https://stackoverflow.com/a/18526649/4224646
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     # labels=trans_format("log10", math_format(10^.x))) +
#     scale_y_log10(
#         breaks=trans_breaks("log10", function(x) 10^x),
#     labels=trans_format("log10", math_format(10^.x))
#     ) +
#     scale_x_log10(
#         breaks=unique(hitting_evaluations_q$l)
#     # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     facet_grid(. ~ `kind`, scales = "free_x") +
#     labs(x=expression("String length (" ~ l ~ ")"), y="#evaluations", shape="Approach:", color="Approach:", fill="Approach:") +
#     theme_bw() +
#     theme(strip.background = element_rect(fill = NA, color=NA)) +
#     theme(strip.background = element_rect(fill = NA, color=NA)) + theme(
#         axis.text.x = element_blank(),
#         axis.title.x = element_blank(),
#         axis.ticks.x = element_blank()
#     ) +
#     theme(plot.margin = margin(b = 2, unit = "pt"))
#
#
# plt_time <- ggplot(hitting_time_q, aes(x=l, y=`0.5`, ymin=`0.05`, ymax=`0.95`, shape=`approach`, color=`approach`, fill=`approach`)) +
#     geom_line() +
#     geom_point() +
#     geom_ribbon(alpha=0.1, color=NA) +
#     # Nice axis labels courtesy of https://stackoverflow.com/a/18526649/4224646
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     # labels=trans_format("log10", math_format(10^.x))) +
#     scale_y_log10(
#         breaks=trans_breaks("log10", function(x) 10^x),
#     labels=trans_format("log10", math_format(10^.x))
#     ) +
#     scale_x_log10(
#         breaks=unique(hitting_time_q$l)
#     # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     facet_grid(. ~ `kind`, scales = "free_x") +
#     labs(x=expression("String length (" ~ l ~ ")"), y="Time (ms)", shape="Approach:", color="Approach:", fill="Approach:") +
#     theme_bw() +
#     theme(strip.text = element_blank()) + theme(plot.margin = margin(t = 2, unit = "pt"))
#     #guides(color=guide_legend(nrow=2,byrow=TRUE), fill=guide_legend(nrow=2, byrow=TRUE), shape=guide_legend(nrow=2, byrow=TRUE),) +
#
#
# plt <- ((plt_eval + theme(legend.position="bottom")) / (plt_time + theme(legend.position="bottom"))) +
#     plot_layout(guides = 'collect') & theme(legend.position="bottom")
# # ggsave("./2021-12-23-paper_maxcut_scalability_evalandtime.png")
# # ggsave("./2021-12-23-paper_maxcut_scalability_evalandtime.pdf", device=cairo_pdf)
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_evalandtime_lb.png")
# ggsave("./2022-01-25-paper_maxcut_wo_maxcut_scalability_evalandtime_lb.pdf", device=cairo_pdf)
# plt
# Out:
# R[write to console]: Saving 6.94 x 4.17 in image
#
# R[write to console]: Saving 6.94 x 4.17 in image

# %% [markdown]
# # Reliability
# How often does the approach actually find the optimum?

# %%
def count_ratio_finite(df):
    return np.mean(np.isfinite(df))
ratio_success = hitting_evaluations.groupby(setting_columns)["hitting #evaluations"].apply(count_ratio_finite).rename("P(success)").reset_index()

ratio_success_style = ratio_success.pivot(["l", "kind"], "approach", "P(success)").style.background_gradient(cmap='gray', axis=1, vmin=0, vmax=1)
ratio_success_style
# Out:
# <style type="text/css">
# #T_068f3_row0_col0, #T_068f3_row0_col1, #T_068f3_row0_col2, #T_068f3_row0_col3, #T_068f3_row1_col0, #T_068f3_row1_col1, #T_068f3_row1_col2, #T_068f3_row1_col3, #T_068f3_row2_col0, #T_068f3_row2_col1, #T_068f3_row2_col2, #T_068f3_row2_col3, #T_068f3_row3_col0, #T_068f3_row3_col1, #T_068f3_row3_col2, #T_068f3_row3_col3, #T_068f3_row4_col0, #T_068f3_row4_col1, #T_068f3_row4_col2, #T_068f3_row4_col3, #T_068f3_row5_col0, #T_068f3_row5_col1, #T_068f3_row5_col2, #T_068f3_row5_col3, #T_068f3_row6_col0, #T_068f3_row6_col1, #T_068f3_row6_col2, #T_068f3_row6_col3, #T_068f3_row7_col0, #T_068f3_row7_col1, #T_068f3_row7_col2, #T_068f3_row7_col3, #T_068f3_row8_col0, #T_068f3_row8_col1, #T_068f3_row8_col2, #T_068f3_row8_col3, #T_068f3_row9_col2, #T_068f3_row9_col3, #T_068f3_row10_col1, #T_068f3_row10_col2 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_068f3_row9_col0, #T_068f3_row9_col1 {
#   background-color: #999999;
#   color: #f1f1f1;
# }
# #T_068f3_row10_col0 {
#   background-color: #5d5d5d;
#   color: #f1f1f1;
# }
# #T_068f3_row10_col3 {
#   background-color: #f7f7f7;
#   color: #000000;
# }
# </style>
# <table id="T_068f3_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >approach</th>
#       <th class="col_heading level0 col0" >DSMGA-II</th>
#       <th class="col_heading level0 col1" >GOMEA</th>
#       <th class="col_heading level0 col2" >LK-GOMEA (Asym)</th>
#       <th class="col_heading level0 col3" >LK-GOMEA (Sym)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >l</th>
#       <th class="index_name level1" >kind</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_068f3_level0_row0" class="row_heading level0 row0" rowspan="2">6</th>
#       <th id="T_068f3_level1_row0" class="row_heading level1 row0" >MaxCut</th>
#       <td id="T_068f3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_068f3_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_068f3_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_068f3_row0_col3" class="data row0 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level1_row1" class="row_heading level1 row1" >Worst-of-MaxCuts</th>
#       <td id="T_068f3_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_068f3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_068f3_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_068f3_row1_col3" class="data row1 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level0_row2" class="row_heading level0 row2" rowspan="2">12</th>
#       <th id="T_068f3_level1_row2" class="row_heading level1 row2" >MaxCut</th>
#       <td id="T_068f3_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_068f3_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_068f3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_068f3_row2_col3" class="data row2 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level1_row3" class="row_heading level1 row3" >Worst-of-MaxCuts</th>
#       <td id="T_068f3_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_068f3_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_068f3_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_068f3_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level0_row4" class="row_heading level0 row4" rowspan="2">25</th>
#       <th id="T_068f3_level1_row4" class="row_heading level1 row4" >MaxCut</th>
#       <td id="T_068f3_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_068f3_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_068f3_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_068f3_row4_col3" class="data row4 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level1_row5" class="row_heading level1 row5" >Worst-of-MaxCuts</th>
#       <td id="T_068f3_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_068f3_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_068f3_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_068f3_row5_col3" class="data row5 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level0_row6" class="row_heading level0 row6" rowspan="2">50</th>
#       <th id="T_068f3_level1_row6" class="row_heading level1 row6" >MaxCut</th>
#       <td id="T_068f3_row6_col0" class="data row6 col0" >1.000000</td>
#       <td id="T_068f3_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_068f3_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_068f3_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level1_row7" class="row_heading level1 row7" >Worst-of-MaxCuts</th>
#       <td id="T_068f3_row7_col0" class="data row7 col0" >1.000000</td>
#       <td id="T_068f3_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_068f3_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_068f3_row7_col3" class="data row7 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level0_row8" class="row_heading level0 row8" rowspan="2">100</th>
#       <th id="T_068f3_level1_row8" class="row_heading level1 row8" >MaxCut</th>
#       <td id="T_068f3_row8_col0" class="data row8 col0" >1.000000</td>
#       <td id="T_068f3_row8_col1" class="data row8 col1" >1.000000</td>
#       <td id="T_068f3_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_068f3_row8_col3" class="data row8 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level1_row9" class="row_heading level1 row9" >Worst-of-MaxCuts</th>
#       <td id="T_068f3_row9_col0" class="data row9 col0" >0.600000</td>
#       <td id="T_068f3_row9_col1" class="data row9 col1" >0.600000</td>
#       <td id="T_068f3_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_068f3_row9_col3" class="data row9 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_068f3_level0_row10" class="row_heading level0 row10" >200</th>
#       <th id="T_068f3_level1_row10" class="row_heading level1 row10" >MaxCut</th>
#       <td id="T_068f3_row10_col0" class="data row10 col0" >0.366667</td>
#       <td id="T_068f3_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_068f3_row10_col2" class="data row10 col2" >1.000000</td>
#       <td id="T_068f3_row10_col3" class="data row10 col3" >0.966667</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%R -i ratio_success -w 500 -h 300
# plt <- ggplot(ratio_success, aes(x=`l`, y=`P(success)`, color=`approach`, shape=`approach`)) +
#     geom_point() +
#     geom_line() +
#     ylim(0, 1) +
#     # scale_x_log10(
#     #     breaks=trans_breaks("log10", function(x) 10^x),
#     #     labels=trans_format("log10", math_format(10^.x))) +
#     scale_x_log10(
#         breaks=unique(ratio_success$l)
#     # labels=trans_format("log10", math_format(10^.x))
#     ) +
#     labs(x=expression("string length (" ~ l ~ ")")) +
#     theme_bw() +
#     theme(strip.background = element_rect(fill = NA, color=NA))
#
# ggsave("./2022-01-25-paper_wo_maxcut_reliability.png")
# ggsave("./2022-01-25-paper_wo_maxcut_reliability.pdf", device = cairo_pdf)
# plt
# Out:
# R[write to console]: Saving 6.94 x 4.17 in image
#
# R[write to console]: Saving 6.94 x 4.17 in image

# %%
subset = ["approach", "l", 0.5]
hitting_medians = pd.merge(hitting_evaluations_q[subset], hitting_time_q[subset], on=["approach", "l"], suffixes=("_evaluations", "_time"))
hitting_medians
# Out:
#            approach    l  0.5_evaluations   0.5_time
# 0            DSMGA2    6             12.0        1.0
# 1            DSMGA2   12            529.5        2.0
# 2            DSMGA2   25           3785.5       10.5
# 3            DSMGA2   50          55128.0      306.0
# 4            DSMGA2  100       52927575.0   870892.5
# 5             GOMEA    6             37.0        1.0
# 6             GOMEA   12            731.0        2.0
# 7             GOMEA   25           2478.0        5.0
# 8             GOMEA   50          32995.0       96.5
# 9             GOMEA  100       49709152.5  2203303.0
# 10  LK-GOMEA (Asym)    6             29.0        1.0
# 11  LK-GOMEA (Asym)   12            668.5        4.5
# 12  LK-GOMEA (Asym)   25           7592.5       57.5
# 13  LK-GOMEA (Asym)   50          56462.5      759.5
# 14  LK-GOMEA (Asym)  100        7095108.5   360411.5
# 15   LK-GOMEA (Sym)    6             41.0        1.0
# 16   LK-GOMEA (Sym)   12            673.0        4.0
# 17   LK-GOMEA (Sym)   25           4505.5       34.0
# 18   LK-GOMEA (Sym)   50          37644.5      465.0
# 19   LK-GOMEA (Sym)  100        5209439.0   275196.5

# %% [markdown]
# # Tabulation

# %%
# %%R -i hitting_medians
# tab <- hitting_medians %>%
#     rename(`evaluations` = `0.5_evaluations`, `time (ms)`=`0.5_time`) %>%
#     pivot_wider(names_from = approach, values_from=c(`evaluations`, `time (ms)`), names_sep= ".") %>%
#     gt() %>%
#     tab_header(title="Hitting evaluations & time for MaxCut") %>%
#     fmt_integer(starts_with("evaluations")) %>%
#     tab_spanner_delim('.') %>%
#     tab_style(style = cell_fill(color = "ghostwhite"), cells_body(columns=starts_with("time (ms)")))
#     # data_color(starts_with("evaluations"), "white") %>%
#     # data_color(starts_with("time (ms)"), "ghostwhite")
#
# tab %>% gtsave("2021-12-23-paper_maxcut_table_evals_and_time_median.tex")
# tab

# %% [markdown]
# # Statistical Significance
# Our goal is to compare the scalability of the approaches, and as such compare the limiting behavior. We therefore perform all pairwise statistical tests for the highest value of $l$, and if applicable, for each value of $\mathit{fns}$. Due to the multiplicitity of comparisons we perform the Holm–Bonferroni* correction. A summary of the number of cases in which an approach is better (i.e. requires less time or evaluations) is provided in Table~[INSERT REFERENCE HERE], details and individual comparisons can be found in the supplementary material.

# %%
# For evaluations
l_max = hitting_evaluations["l"].max()
hitting_evaluations_l_max = hitting_evaluations[hitting_evaluations["l"] == l_max]
hitting_evaluations_l_max_by_approach = hitting_evaluations_l_max.groupby(setting_columns)["hitting #evaluations"].apply(list).reset_index()
a = 2 * 0.05 # 2 * as tests are correlated and corrected for count: one out of two tests is guaranteed to fail.

from scipy.stats import mannwhitneyu

# Create pairs
pairs_df = pd.merge(hitting_evaluations_l_max_by_approach, hitting_evaluations_l_max_by_approach, how="cross")
# Filter out same set of samples
pairs_df = pairs_df[pairs_df["approach_x"] != pairs_df['approach_y']]
def perform_test_on_pair(df):
    return mannwhitneyu(
        np.nan_to_num(df["hitting #evaluations_x"], nan=np.inf),
        np.nan_to_num(df["hitting #evaluations_y"], nan=np.inf),
        use_continuity = False, alternative="less")

pairs_df[["test statistic", "test p"]] = pairs_df.apply(perform_test_on_pair, axis=1).apply(pd.Series)

# Holm–Bonferroni
def perform_comparison(df):
    df = df.sort_values(["test p"])
    df["H0 accepted"] = (df["test p"] < a / (len(df) - np.arange(0, len(df)))).expanding().min()
    return df

pairs_df = perform_comparison(pairs_df).reset_index(drop = True)
# Bonferroni (does the better correction actually impact the result?)
# pairs_df = pairs_df.sort_values("test p")
# pairs_df["H0 accepted"] = pairs_df["test p"] < a / len(pairs_df)
# Note to self: it does not.

# tests_df
# tests_df.pivot("approach a", "approach b", "test p")
signficant_evaluations = pairs_df.sort_values(["approach_x", "approach_y"]).pivot(["approach_x"], ["approach_y"], "H0 accepted")
test_p_evaluations = pairs_df.sort_values(["approach_x", "approach_y"]).pivot(["approach_x"], ["approach_y"], "test p")
# signficant_evaluations.to_latex("./2021-12-23-paper_maxcut_significant_evaluations.tex")
# signficant_evaluations
def styled(df):
    def get_style(m):
        if m is np.nan:
            return f"background-color: #d3d3d3; color: #000000;"
        if m:
            return f"background-color: #ffffff; color: #000000;"
        else:
            return f"background-color: #808080; color: #ffffff;"
    map_a = signficant_evaluations.applymap(get_style)
    map_a[np.isnan(df)] = f"background-color: #d3d3d3; color: #000000;"

    return map_a

test_p_evaluations_styled = test_p_evaluations.style.apply(styled, axis=None).format(na_rep="-", precision=3)
test_p_evaluations_styled.to_latex("./2022-01-25-paper_wo_maxcut_significant_evaluations.tex", hrules=True, convert_css=True)
test_p_evaluations_styled
# Out:
# <style type="text/css">
# #T_e3ac5_row0_col0, #T_e3ac5_row1_col1, #T_e3ac5_row2_col2, #T_e3ac5_row3_col3 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_e3ac5_row0_col1, #T_e3ac5_row0_col2, #T_e3ac5_row0_col3, #T_e3ac5_row1_col0, #T_e3ac5_row1_col2, #T_e3ac5_row1_col3, #T_e3ac5_row2_col3, #T_e3ac5_row3_col2 {
#   background-color: #808080;
#   color: #ffffff;
# }
# #T_e3ac5_row2_col0, #T_e3ac5_row2_col1, #T_e3ac5_row3_col0, #T_e3ac5_row3_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_e3ac5_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >approach_y</th>
#       <th class="col_heading level0 col0" >DSMGA2</th>
#       <th class="col_heading level0 col1" >GOMEA</th>
#       <th class="col_heading level0 col2" >LK-GOMEA (Asym)</th>
#       <th class="col_heading level0 col3" >LK-GOMEA (Sym)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >approach_x</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3ac5_level0_row0" class="row_heading level0 row0" >DSMGA2</th>
#       <td id="T_e3ac5_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_e3ac5_row0_col1" class="data row0 col1" >0.688</td>
#       <td id="T_e3ac5_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_e3ac5_row0_col3" class="data row0 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3ac5_level0_row1" class="row_heading level0 row1" >GOMEA</th>
#       <td id="T_e3ac5_row1_col0" class="data row1 col0" >0.312</td>
#       <td id="T_e3ac5_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_e3ac5_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_e3ac5_row1_col3" class="data row1 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_e3ac5_level0_row2" class="row_heading level0 row2" >LK-GOMEA (Asym)</th>
#       <td id="T_e3ac5_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_e3ac5_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_e3ac5_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_e3ac5_row2_col3" class="data row2 col3" >0.733</td>
#     </tr>
#     <tr>
#       <th id="T_e3ac5_level0_row3" class="row_heading level0 row3" >LK-GOMEA (Sym)</th>
#       <td id="T_e3ac5_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_e3ac5_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_e3ac5_row3_col2" class="data row3 col2" >0.267</td>
#       <td id="T_e3ac5_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#   </tbody>
# </table>

# %%
# For time
l_max = hitting_time["l"].max()
hitting_time_l_max = hitting_time[hitting_time["l"] == l_max]
hitting_time_l_max_by_approach = hitting_time_l_max.groupby(setting_columns)["hitting time (ms)"].apply(list).reset_index()
a = 2 * 0.05 # 2 * as tests are correlated and corrected for count: one out of two tests is guaranteed to fail.

from scipy.stats import mannwhitneyu

# Create pairs
pairs_df = pd.merge(hitting_time_l_max_by_approach, hitting_time_l_max_by_approach, how="cross")
# Filter out same set of samples
pairs_df = pairs_df[pairs_df["approach_x"] != pairs_df['approach_y']]
def perform_test_on_pair(df):
    return mannwhitneyu(
        np.nan_to_num(df["hitting time (ms)_x"], nan=np.inf),
        np.nan_to_num(df["hitting time (ms)_y"], nan=np.inf),
        use_continuity = False, alternative="less")

pairs_df[["test statistic", "test p"]] = pairs_df.apply(perform_test_on_pair, axis=1).apply(pd.Series)

# Holm–Bonferroni
def perform_comparison(df):
    df = df.sort_values(["test p"])
    df["H0 accepted"] = (df["test p"] < a / (len(df) - np.arange(0, len(df)))).expanding().min()
    return df

pairs_df = perform_comparison(pairs_df).reset_index(drop = True)
# Bonferroni (does the better correction actually impact the result?)
# pairs_df = pairs_df.sort_values("test p")
# pairs_df["H0 accepted"] = pairs_df["test p"] < a / len(pairs_df)
# Note to self: it does not.

# tests_df
# tests_df.pivot("approach a", "approach b", "test p")
signficant_time = pairs_df.sort_values(["approach_x", "approach_y"]).pivot(["approach_x"], ["approach_y"], "H0 accepted")
test_p_time = pairs_df.sort_values(["approach_x", "approach_y"]).pivot(["approach_x"], ["approach_y"], "test p")
# signficant_time.to_latex("./2021-12-23-paper_maxcut_significant_time.tex")
# signficant_time
def styled(df):
    def get_style(m):
        if m is np.nan:
            return f"background-color: #d3d3d3; color: #000000;"
        if m:
            return f"background-color: #ffffff; color: #000000;"
        else:
            return f"background-color: #808080; color: #ffffff;"
    map_a = signficant_time.applymap(get_style)
    map_a[np.isnan(df)] = f"background-color: #d3d3d3; color: #000000;"

    return map_a

test_p_time_styled = test_p_time.style.apply(styled, axis=None).format(na_rep="-", precision=3)
test_p_time_styled.to_latex("./2022-01-25-paper_wo_maxcut_significant_time.tex", hrules=True, convert_css=True)
test_p_time_styled
# Out:
# <style type="text/css">
# #T_1b6de_row0_col0, #T_1b6de_row1_col1, #T_1b6de_row2_col2, #T_1b6de_row3_col3 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_1b6de_row0_col1, #T_1b6de_row0_col2, #T_1b6de_row0_col3, #T_1b6de_row1_col0, #T_1b6de_row1_col2, #T_1b6de_row1_col3, #T_1b6de_row2_col3, #T_1b6de_row3_col2 {
#   background-color: #808080;
#   color: #ffffff;
# }
# #T_1b6de_row2_col0, #T_1b6de_row2_col1, #T_1b6de_row3_col0, #T_1b6de_row3_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_1b6de_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >approach_y</th>
#       <th class="col_heading level0 col0" >DSMGA2</th>
#       <th class="col_heading level0 col1" >GOMEA</th>
#       <th class="col_heading level0 col2" >LK-GOMEA (Asym)</th>
#       <th class="col_heading level0 col3" >LK-GOMEA (Sym)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >approach_x</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b6de_level0_row0" class="row_heading level0 row0" >DSMGA2</th>
#       <td id="T_1b6de_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_1b6de_row0_col1" class="data row0 col1" >0.561</td>
#       <td id="T_1b6de_row0_col2" class="data row0 col2" >0.999</td>
#       <td id="T_1b6de_row0_col3" class="data row0 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_1b6de_level0_row1" class="row_heading level0 row1" >GOMEA</th>
#       <td id="T_1b6de_row1_col0" class="data row1 col0" >0.439</td>
#       <td id="T_1b6de_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_1b6de_row1_col2" class="data row1 col2" >0.998</td>
#       <td id="T_1b6de_row1_col3" class="data row1 col3" >0.997</td>
#     </tr>
#     <tr>
#       <th id="T_1b6de_level0_row2" class="row_heading level0 row2" >LK-GOMEA (Asym)</th>
#       <td id="T_1b6de_row2_col0" class="data row2 col0" >0.001</td>
#       <td id="T_1b6de_row2_col1" class="data row2 col1" >0.002</td>
#       <td id="T_1b6de_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_1b6de_row2_col3" class="data row2 col3" >0.671</td>
#     </tr>
#     <tr>
#       <th id="T_1b6de_level0_row3" class="row_heading level0 row3" >LK-GOMEA (Sym)</th>
#       <td id="T_1b6de_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_1b6de_row3_col1" class="data row3 col1" >0.003</td>
#       <td id="T_1b6de_row3_col2" class="data row3 col2" >0.329</td>
#       <td id="T_1b6de_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#   </tbody>
# </table>

# %%
partial_sum_maxcut_evaluations = signficant_evaluations.stack().groupby("approach_x").sum()
partial_sum_maxcut_time = signficant_time.stack().groupby("approach_x").sum()
partial_sum_maxcut_evaluations.to_csv("counts_maxcut_evaluations.csv")
partial_sum_maxcut_time.to_csv("counts_maxcut_time.csv")
display(partial_sum_maxcut_evaluations)
display(partial_sum_maxcut_time)
# Out:
# approach_x
# DSMGA2             0.0
# GOMEA              2.0
# LK-GOMEA (Asym)    1.0
# LK-GOMEA (Sym)     1.0
# dtype: float64
# approach_x
# DSMGA2             0.0
# GOMEA              3.0
# LK-GOMEA (Asym)    1.0
# LK-GOMEA (Sym)     1.0
# dtype: float64
